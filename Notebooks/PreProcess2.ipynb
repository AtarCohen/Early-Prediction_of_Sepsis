# %% [markdown]
# <h1> Pre Process </h1>

# %%
import pandas as pd
import os
import tqdm

# %%
df = pd.read_csv('filtered_train_data_combined.csv')
std = pd.read_csv('stds_train_data.csv')

# %%
from matplotlib import pyplot as plt
import seaborn as sns;
sns.set(style="white", color_codes=True)
def plot_results(cols,rows, cols_names,df, types, title=None):
    fig,axes = plt.subplots(rows,cols, figsize=(20,20))
    # fig.tight_layout(pad=3.0)
    axes = axes.ravel()
    for i,col in enumerate(cols_names):
        type = types[i]
        # if col!='Label':
        if type=='hist':
            sns.histplot(x=col,hue='Label',data=df, multiple="dodge", ax=axes[i])
            axes[i].set_title(col+' distribution by label')
        if type=='dist':
            sns.distplot(df[df['Label']==1][col], color='r',ax=axes[i])
            sns.distplot(df[df['Label']==0][col],ax=axes[i])
            axes[i].set_title(col+' distribution by label')
        elif type=='ts':
            axes[i].plot(df[df['Label']==1]['time_bm'],df[df['Label']==1][col], color='r')
            axes[i].plot(df[df['Label']==0]['time_bm'],df[df['Label']==0][col], color='b')
            axes[i].set_title(col+' change over time by label')
        elif type=='cat':
            sns.countplot(x=col, hue='Label', data=df, ax=axes[i])
            axes[i].set_title(col+' distribution by label')
        # else:
        #     sns.histplot(x=col,data=df, color='g',ax=axes[i])
        #     axes[i].set_title(col+' distribution')
    if title:
        plt.suptitle(title)

# %%
demo_cols = ['Age', 'Gender', 'Label', 'ICULOS']
demographic_df = df[demo_cols+['ID']].groupby(by='ID').max()

plot_results(2,2,demo_cols,demographic_df,types=['dist','cat','cat','dist'])
# Out:
# /data/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /data/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
max_los = df[['ID','ICULOS']].groupby(by='ID').max().rename(columns={'ICULOS':'Max_ICULOS'})
max_los
# Out:
#        Max_ICULOS
# ID
# 0              23
# 1              26
# 2              38
# 3              48
# 4              24
# ...           ...
# 19995          29
# 19996          43
# 19997          15
# 19998          42
# 19999          54
#
# [20000 rows x 1 columns]

# %%
df=df.join(max_los,on='ID',how='left')
df['time_bm'] =  df['ICULOS']-df['Max_ICULOS']
df
# Out:
#         Unnamed: 0     HR  O2Sat  Temp    SBP    MAP    DBP  Resp  EtCO2  \
# 0                0    NaN    NaN   NaN    NaN    NaN    NaN   NaN    NaN
# 1                1   58.5   96.0   NaN  133.0   54.0   30.0  28.5    NaN
# 2                2   54.0   97.0  36.4  128.0   58.0   36.0  23.0    NaN
# 3                3   58.0   97.0   NaN  116.0   50.0   28.0  21.0    NaN
# 4                4   58.0   98.0   NaN  128.0   65.0   49.0  32.0    NaN
# ...            ...    ...    ...   ...    ...    ...    ...   ...    ...
# 754812          32   85.0   92.0   NaN  116.0   93.0   79.0  20.0    NaN
# 754813          33   87.0   94.0  36.9  137.0  107.0   91.0  26.0    NaN
# 754814          34  121.0   97.0   NaN    NaN    NaN    NaN  22.0    NaN
# 754815          35   95.0   91.0   NaN  138.5  107.0   87.5  20.0    NaN
# 754816          36  122.0  100.0   NaN  169.0  139.0  116.0  20.0    NaN
#
#         BaseExcess  ...  Gender  Unit1  Unit2  HospAdmTime  ICULOS  \
# ...

# %%
lab_attr= list(df.columns[9:35])
df[['ID','ICULOS']+lab_attr].groupby(by='ID').count()
# Out:
#        ICULOS  BaseExcess  HCO3  FiO2  pH  PaCO2  SaO2  AST  BUN  \
# ID
# 0          23           0     1     0   0      0     0    0    1
# 1          25           3     3     6   3      3     0    0    2
# 2          36           0     1     3   0      0     0    1    1
# 3          45           0     2     0   0      0     0    0    2
# 4          24           0     0     0   0      0     0    0    1
# ...       ...         ...   ...   ...  ..    ...   ...  ...  ...
# 19995      29           2     0     7   4      2     2    0    1
# 19996      43           5     2    14   5      5     0    0    2
# 19997      14           0     1     0   0      0     0    0    1
# 19998      41           3     3     9   4      3     0    0    3
# 19999      54           7     2     4   7      6     4    1    2
#
#        Alkalinephos  ...  Phosphate  Potassium  Bilirubin_total  TroponinI  \
# ID                   ...
# 0                 0  ...          1          1                0          0
# ...

# %%
df['num_lab_vals'] = None
num_lab_vals_list = []
for index, row in df.iterrows():
    counter = 0
    for col in lab_attr:
        # print(row[col], str(row[col])!='nan')
        if (str(row[col])!='nan'):
            counter += 1
    num_lab_vals_list.append(counter)
    # row['num_lab_vals'] = counter
    # if index < 30:
    #     print(index, row[['ID','ICULOS', 'num_lab_vals']+lab_attr])

# %%
df['num_lab_vals'] = num_lab_vals_list

# %%
df[['ID','ICULOS', 'time_bm', 'num_lab_vals']+lab_attr]
# Out:
#            ID  ICULOS  time_bm  num_lab_vals  BaseExcess  HCO3  FiO2  pH  \
# 0       10022       1      -51             0         NaN   NaN   NaN NaN
# 1       10022       2      -50             0         NaN   NaN   NaN NaN
# 2       10022       3      -49             1         NaN   NaN   NaN NaN
# 3       10022       4      -48             0         NaN   NaN   NaN NaN
# 4       10022       5      -47             0         NaN   NaN   NaN NaN
# ...       ...     ...      ...           ...         ...   ...   ...  ..
# 754812   8234      33       -4             0         NaN   NaN   NaN NaN
# 754813   8234      34       -3             0         NaN   NaN   NaN NaN
# 754814   8234      35       -2             1         NaN   NaN   NaN NaN
# 754815   8234      36       -1             0         NaN   NaN   NaN NaN
# 754816   8234      37        0             0         NaN   NaN   NaN NaN
#
#         PaCO2  SaO2  ...  Phosphate  Potassium  Bilirubin_total  TroponinI  \
# ...

# %%
plt.figure(figsize=(11,5))
plt.scatter(df['time_bm'][df['Label']==1], df['num_lab_vals'][df['Label']==1], marker='*', label="1", c="red", alpha=0.25, s=2)
plt.scatter(df['time_bm'][df['Label']==0], df['num_lab_vals'][df['Label']==0], marker='+',label="0", c="blue", alpha=0.25, s=2)
# plt.scatter(min_var_std, min_var_m, label="Min. variance portfolio", c="green")
# plt.scatter(best_basket_std, best_basket_m, label="Best basket portfolio", c="red")
plt.xlabel("time_bm")
plt.ylabel("number of lab values")
plt.title("number of lab values by time")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(11,5))
plt.scatter(df['time_bm'][(df['Label']==1)&(df['time_bm']>-51)], df['num_lab_vals'][(df['Label']==1)&(df['time_bm']>-51)], label="1", marker='*', c="red", alpha=0.25, s=2)
plt.scatter(df['time_bm'][(df['Label']==0)&(df['time_bm']>-51)], df['num_lab_vals'][(df['Label']==0)&(df['time_bm']>-51)], label="0", marker='+', c="blue", alpha=0.25, s=2)
# plt.scatter(min_var_std, min_var_m, label="Min. variance portfolio", c="green")
# plt.scatter(best_basket_std, best_basket_m, label="Best basket portfolio", c="red")
plt.xlabel("time_bm")
plt.ylabel("number of lab values")
plt.title("number of lab values by time")
plt.legend()
plt.grid()
plt.show()
# Out:
# /data/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from matplotlib import pyplot as plt
import seaborn as sns;
sns.set(style="white", color_codes=True)
col = 'num_lab_vals'
# fig,axes = plt.subplots(rows,cols, figsize=(12,6))
sns.distplot(df[df['Label']==1][col], color='r')
sns.distplot(df[df['Label']==0][col])
# axes[i].set_title(col+' distribution by label')
# Out:
# /data/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /data/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='num_lab_vals', ylabel='Density'>
